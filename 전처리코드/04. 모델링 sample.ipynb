# %%
import gpxpy
import matplotlib.pyplot as plt
import pandas as pd

# %%
with open('C:/Users/박연재/Desktop/빅리더_프로젝트/국립공원공단/트랭글데이터/2019_seperate/1/done_4002.gpx') as fh:
    gpx_file1 = gpxpy.parse(fh)
segment1 = gpx_file1.tracks[0].segments[0]
coords1 = pd.DataFrame([
    {'idx':0,
     'lat': p.latitude,
     'lon': p.longitude,
     'ele': p.elevation,
     'time': p.time} for p in segment1.points])


with open('C:/Users/박연재/Desktop/빅리더_프로젝트/국립공원공단/트랭글데이터/2019_seperate/1/done_3315.gpx') as fh:
    gpx_file2 = gpxpy.parse(fh)
segment2 = gpx_file2.tracks[0].segments[0]
coords2 = pd.DataFrame([
    {'idx':1,
     'lat': p.latitude,
     'lon': p.longitude,
     'ele': p.elevation,
     'time': p.time} for p in segment2.points])

with open('C:/Users/박연재/Desktop/빅리더_프로젝트/국립공원공단/트랭글데이터/2019_seperate/1/done_4367.gpx') as fh:
    gpx_file3 = gpxpy.parse(fh)
segment3 = gpx_file3.tracks[0].segments[0]
coords3 = pd.DataFrame([
    {'idx':2,
     'lat': p.latitude,
     'lon': p.longitude,
     'ele': p.elevation,
     'time': p.time} for p in segment3.points])

with open('C:/Users/박연재/Desktop/빅리더_프로젝트/국립공원공단/트랭글데이터/2019_seperate/1/done_4231.gpx') as fh:
    gpx_file4 = gpxpy.parse(fh)
segment4 = gpx_file4.tracks[0].segments[0]
coords4 = pd.DataFrame([
    {'idx':3,
     'lat': p.latitude,
     'lon': p.longitude,
     'ele': p.elevation,
     'time': p.time} for p in segment4.points])

with open('C:/Users/박연재/Desktop/빅리더_프로젝트/국립공원공단/트랭글데이터/2019_seperate/1/done_4427.gpx') as fh:
    gpx_file5 = gpxpy.parse(fh)
segment5 = gpx_file5.tracks[0].segments[0]
coords5 = pd.DataFrame([
    {'idx':4,
     'lat': p.latitude,
     'lon': p.longitude,
     'ele': p.elevation,
     'time': p.time} for p in segment5.points])

# %%
#plt.figure(figsize=(10,10))

plt.plot(coords1.lon[::1], coords1.lat[::1], 'b-')
plt.plot(coords2.lon[::1], coords2.lat[::1], 'b-')
plt.plot(coords3.lon[::1], coords3.lat[::1], 'b-')
plt.plot(coords4.lon[::1], coords4.lat[::1], 'b-')
plt.plot(coords5.lon[::1], coords5.lat[::1], 'b-')

plt.show()

# %%
df = pd.concat([coords1,coords2,coords3,coords4,coords5], ignore_index=True)
df
# Out:
#       idx        lat         lon         ele                      time
# 0       0  37.658196  126.991380  326.236547 2019-01-01 05:47:07+00:00
# 1       0  37.658220  126.991177  319.576703 2019-01-01 05:47:19+00:00
# 2       0  37.658239  126.991029  319.537884 2019-01-01 05:47:28+00:00
# 3       0  37.658263  126.990935  317.040334 2019-01-01 05:47:42+00:00
# 4       0  37.658319  126.990857  316.141873 2019-01-01 05:47:51+00:00
# ...   ...        ...         ...         ...                       ...
# 1951    4  37.657993  126.991224  371.791477 2019-01-01 09:57:11+00:00
# 1952    4  37.657959  126.991287  371.791477 2019-01-01 09:57:27+00:00
# 1953    4  37.657934  126.991318  350.232349 2019-01-01 09:59:52+00:00
# 1954    4  37.657972  126.991639  340.772183 2019-01-01 10:02:30+00:00
# 1955    4  37.657920  126.991745  366.837289 2019-01-01 10:02:41+00:00
#
# [1956 rows x 5 columns]

# %%
track = df.loc[df['idx'] == 0]
plt.plot(track.lat, track.lon)

# %%
for i in df['idx'].unique():
    track = df.loc[df['idx'] == i]
    plt.plot(track.lat, track.lon)

plt.show()

# for i in df2019['f_Idx'].unique():
#     track2019 = df2019.loc[df2019['f_Idx'] == i]
#     plt.plot(track2019.p_Lon[::1], track2019.p_Lat[::1])

# plt.show()

# %%
fig,ax=plt.subplots(nrows=2,ncols=2)

ax[0,0].plot(coords1.lon[::1], coords1.lat[::1])

ax[0,1].plot(coords2.lon[::1], coords2.lat[::1])

ax[1,0].plot(coords3.lon[::1], coords3.lat[::1])

ax[1,1].plot(coords4.lon[::1], coords4.lat[::1])

plt.show()

# %%
with open('C:/Users/박연재/Desktop/빅리더_프로젝트/국립공원공단/트랭글데이터/2019_done/done_4002.gpx') as fh:
    gpx_file1 = gpxpy.parse(fh)
segment1 = gpx_file1.tracks[0].segments[0]
coords1 = pd.DataFrame([
    {'idx':0,
     'lat': p.latitude,
     'lon': p.longitude,
     'ele': p.elevation,
     'time': p.time} for p in segment1.points])


with open('C:/Users/박연재/Desktop/빅리더_프로젝트/국립공원공단/트랭글데이터/2019_done/done_3315.gpx') as fh:
    gpx_file2 = gpxpy.parse(fh)
segment2 = gpx_file2.tracks[0].segments[0]
coords2 = pd.DataFrame([
    {'idx':1,
     'lat': p.latitude,
     'lon': p.longitude,
     'ele': p.elevation,
     'time': p.time} for p in segment2.points])

with open('C:/Users/박연재/Desktop/빅리더_프로젝트/국립공원공단/트랭글데이터/2019_done/done_4367.gpx') as fh:
    gpx_file3 = gpxpy.parse(fh)
segment3 = gpx_file3.tracks[0].segments[0]
coords3 = pd.DataFrame([
    {'idx':2,
     'lat': p.latitude,
     'lon': p.longitude,
     'ele': p.elevation,
     'time': p.time} for p in segment3.points])

with open('C:/Users/박연재/Desktop/빅리더_프로젝트/국립공원공단/트랭글데이터/2019_done/done_4231.gpx') as fh:
    gpx_file4 = gpxpy.parse(fh)
segment4 = gpx_file4.tracks[0].segments[0]
coords4 = pd.DataFrame([
    {'idx':3,
     'lat': p.latitude,
     'lon': p.longitude,
     'ele': p.elevation,
     'time': p.time} for p in segment4.points])

with open('C:/Users/박연재/Desktop/빅리더_프로젝트/국립공원공단/트랭글데이터/2019_done/done_688.gpx') as fh:
    gpx_file5 = gpxpy.parse(fh)
segment5 = gpx_file5.tracks[0].segments[0]
coords5 = pd.DataFrame([
    {'idx':4,
     'lat': p.latitude,
     'lon': p.longitude,
     'ele': p.elevation,
     'time': p.time} for p in segment5.points])

with open('C:/Users/박연재/Desktop/빅리더_프로젝트/국립공원공단/트랭글데이터/2019_done/done_1171.gpx') as fh:
    gpx_file6 = gpxpy.parse(fh)
segment6 = gpx_file5.tracks[0].segments[0]
coords6 = pd.DataFrame([
    {'idx':5,
     'lat': p.latitude,
     'lon': p.longitude,
     'ele': p.elevation,
     'time': p.time} for p in segment6.points])

# %%
fig,ax=plt.subplots(nrows=3,ncols=2)

ax[0,0].plot(coords1.lon[::1], coords1.lat[::1])

ax[0,1].plot(coords2.lon[::1], coords2.lat[::1])

ax[1,0].plot(coords3.lon[::1], coords3.lat[::1])

ax[1,1].plot(coords4.lon[::1], coords4.lat[::1])

ax[2,0].plot(coords5.lon[::1], coords5.lat[::1])

ax[2,1].plot(coords6.lon[::1], coords6.lat[::1])

plt.show()

# %%
df = pd.concat([coords1,coords2,coords3,coords4,coords5,coords6], ignore_index=True)
df
# Out:
#       idx        lat         lon         ele                      time
# 0       0  37.658196  126.991380  326.236547 2019-01-01 05:47:07+00:00
# 1       0  37.658220  126.991177  319.576703 2019-01-01 05:47:19+00:00
# 2       0  37.658239  126.991029  319.537884 2019-01-01 05:47:28+00:00
# 3       0  37.658263  126.990935  317.040334 2019-01-01 05:47:42+00:00
# 4       0  37.658319  126.990857  316.141873 2019-01-01 05:47:51+00:00
# ...   ...        ...         ...         ...                       ...
# 1898    5  37.628500  126.977344  563.181818 2019-01-01 07:00:22+00:00
# 1899    5  37.628413  126.977330  565.818182 2019-01-01 07:00:36+00:00
# 1900    5  37.628320  126.977354  568.000000 2019-01-01 07:00:52+00:00
# 1901    5  37.628224  126.977381  571.300000 2019-01-01 07:01:02+00:00
# 1902    5  37.628135  126.977386  571.909091 2019-01-01 07:01:14+00:00
#
# [1903 rows x 5 columns]

# %%
plt.figure(figsize=(10,10))

for i in df['idx'].unique():
    track = df.loc[df['idx'] == i]
    plt.plot(track.lon[::1], track.lat[::1])

plt.show()
