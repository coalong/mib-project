# %%
import gpxpy
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# # 시작점 고려 안하고 뽑았을 때

# %% [markdown]
# ### 1차

# %%
with open('C:/Users/박연재/Desktop/국립공원공단/트랭글데이터/2019_done/done_1000107.gpx', encoding='utf-8') as fh:
    gpx_file1 = gpxpy.parse(fh) #gpx 파일 불러오기
segment1 = gpx_file1.tracks[0].segments[0]
coords1 = pd.DataFrame([
    {'idx':0,
     'lat': p.latitude, # gpx 파일의 포인트 위도
     'lon': p.longitude, # gpx 파일의 포인트 경도
     'ele': p.elevation, # gpx 파일의 포인트 고도
     'time': p.time} for p in segment1.points]) # gpx 파일의 포인트 시간


with open('C:/Users/박연재/Desktop/국립공원공단/트랭글데이터/2019_done/done_3326363.gpx', encoding='utf-8') as fh:
    gpx_file2 = gpxpy.parse(fh)
segment2 = gpx_file2.tracks[0].segments[0]
coords2 = pd.DataFrame([
    {'idx':1,
     'lat': p.latitude, # gpx 파일의 포인트 위도
     'lon': p.longitude, # gpx 파일의 포인트 경도
     'ele': p.elevation, # gpx 파일의 포인트 고도
     'time': p.time} for p in segment2.points]) # gpx 파일의 포인트 시간

with open('C:/Users/박연재/Desktop/국립공원공단/트랭글데이터/2019_done/done_753710.gpx',encoding='utf-8') as fh:
    gpx_file3 = gpxpy.parse(fh)
segment3 = gpx_file3.tracks[0].segments[0]
coords3 = pd.DataFrame([
    {'idx':2,
     'lat': p.latitude, # gpx 파일의 포인트 위도
     'lon': p.longitude, # gpx 파일의 포인트 경도
     'ele': p.elevation, # gpx 파일의 포인트 고도
     'time': p.time} for p in segment3.points]) # gpx 파일의 포인트 시간

with open('C:/Users/박연재/Desktop/국립공원공단/트랭글데이터/2019_done/done_2588354.gpx',encoding='utf-8') as fh:
    gpx_file4 = gpxpy.parse(fh) 
segment4 = gpx_file4.tracks[0].segments[0]
coords4 = pd.DataFrame([
    {'idx':3,
     'lat': p.latitude, # gpx파일의 포인트 위도
     'lon': p.longitude, # gpx 파일의 포인트 경도
     'ele': p.elevation, # gpx 파일의 고인트 고도
     'time': p.time} for p in segment4.points]) # gpx 파일의 포인트 시간

with open('C:/Users/박연재/Desktop/국립공원공단/트랭글데이터/2019_done/done_1640175.gpx',encoding='utf-8') as fh:
    gpx_file5 = gpxpy.parse(fh)
segment5 = gpx_file5.tracks[0].segments[0]
coords5 = pd.DataFrame([
    {'idx':4,
     'lat': p.latitude, # gpx파일의 포인트 위도
     'lon': p.longitude, #  gpx 파일의 포인트 경도
     'ele': p.elevation, # gpx 파일의 고인트 고도
     'time': p.time} for p in segment5.points]) # gpx 파일의 포인트 시간

with open('C:/Users/박연재/Desktop/국립공원공단/트랭글데이터/2019_done/done_4884424.gpx',encoding='utf-8') as fh:
    gpx_file6 = gpxpy.parse(fh)
segment6 = gpx_file6.tracks[0].segments[0]
coords6 = pd.DataFrame([
    {'idx':4,
     'lat': p.latitude, #  gpx 파일의 포인트 위도
     'lon': p.longitude, #  gpx 파일의 포인트 경도
     'ele': p.elevation, # gpx 파일의 고인트 고도
     'time': p.time} for p in segment6.points]) # gpx 파일의 포인트 시간

# %%
#gpx 파일의 경도와 위도 값으로 plot에 그리기 - 하나의 plot에 겹쳐서 그리기

#plt.figure(figsize=(10,10))

plt.plot(coords1.lon[::1], coords1.lat[::1])
plt.plot(coords2.lon[::1], coords2.lat[::1])
plt.plot(coords3.lon[::1], coords3.lat[::1])
plt.plot(coords4.lon[::1], coords4.lat[::1])
plt.plot(coords5.lon[::1], coords5.lat[::1])
plt.plot(coords6.lon[::1], coords6.lat[::1])

plt.show()

# %%
#gpx 파일의 경도와 위도 값으로 plot에 그리기 - 나누어 그려서 한 번에 보이기ㄴ

fig,ax=plt.subplots(nrows=3,ncols=2)

ax[0,0].plot(coords1.lon[::1], coords1.lat[::1])

ax[0,1].plot(coords2.lon[::1], coords2.lat[::1])

ax[1,0].plot(coords3.lon[::1], coords3.lat[::1])

ax[1,1].plot(coords4.lon[::1], coords4.lat[::1])

ax[2,0].plot(coords5.lon[::1], coords5.lat[::1])

ax[2,1].plot(coords6.lon[::1], coords6.lat[::1])

plt.show()

# %% [markdown]
# ### 2차

# %%
with open('C:/Users/박연재/Desktop/국립공원공단/트랭글데이터/2019_done/done_997163.gpx', encoding='utf-8') as fh:
    gpx_file1 = gpxpy.parse(fh)
segment1 = gpx_file1.tracks[0].segments[0]
coords1 = pd.DataFrame([
    {'idx':0,
     'lat': p.latitude, # 포인트 위도
     'lon': p.longitude, # 포인트 경도
     'ele': p.elevation, # 포인트 고도
     'time': p.time} for p in segment1.points]) # 포인트 시간


with open('C:/Users/박연재/Desktop/국립공원공단/트랭글데이터/2019_done/done_251551.gpx', encoding='utf-8') as fh:
    gpx_file2 = gpxpy.parse(fh)
segment2 = gpx_file2.tracks[0].segments[0]
coords2 = pd.DataFrame([
    {'idx':1,
     'lat': p.latitude,
     'lon': p.longitude,
     'ele': p.elevation,
     'time': p.time} for p in segment2.points])

with open('C:/Users/박연재/Desktop/국립공원공단/트랭글데이터/2019_done/done_883554.gpx',encoding='utf-8') as fh:
    gpx_file3 = gpxpy.parse(fh)
segment3 = gpx_file3.tracks[0].segments[0]
coords3 = pd.DataFrame([
    {'idx':2,
     'lat': p.latitude,
     'lon': p.longitude,
     'ele': p.elevation,
     'time': p.time} for p in segment3.points])

with open('C:/Users/박연재/Desktop/국립공원공단/트랭글데이터/2019_done/done_1471251.gpx',encoding='utf-8') as fh:
    gpx_file4 = gpxpy.parse(fh)
segment4 = gpx_file4.tracks[0].segments[0]
coords4 = pd.DataFrame([
    {'idx':3,
     'lat': p.latitude,
     'lon': p.longitude,
     'ele': p.elevation,
     'time': p.time} for p in segment4.points])

with open('C:/Users/박연재/Desktop/국립공원공단/트랭글데이터/2019_done/done_638366.gpx',encoding='utf-8') as fh:
    gpx_file5 = gpxpy.parse(fh)
segment5 = gpx_file5.tracks[0].segments[0]
coords5 = pd.DataFrame([
    {'idx':4,
     'lat': p.latitude,
     'lon': p.longitude,
     'ele': p.elevation,
     'time': p.time} for p in segment5.points])

with open('C:/Users/박연재/Desktop/국립공원공단/트랭글데이터/2019_done/done_4551553.gpx',encoding='utf-8') as fh:
    gpx_file6 = gpxpy.parse(fh)
segment6 = gpx_file6.tracks[0].segments[0]
coords6 = pd.DataFrame([
    {'idx':4,
     'lat': p.latitude,
     'lon': p.longitude,
     'ele': p.elevation,
     'time': p.time} for p in segment6.points])

# %%
#plt.figure(figsize=(10,10))

plt.plot(coords1.lon[::1], coords1.lat[::1])
plt.plot(coords2.lon[::1], coords2.lat[::1])
plt.plot(coords3.lon[::1], coords3.lat[::1])
plt.plot(coords4.lon[::1], coords4.lat[::1])
plt.plot(coords5.lon[::1], coords5.lat[::1])
plt.plot(coords6.lon[::1], coords6.lat[::1])

plt.show()

# %%
fig,ax=plt.subplots(nrows=3,ncols=2)

ax[0,0].plot(coords1.lon[::1], coords1.lat[::1])

ax[0,1].plot(coords2.lon[::1], coords2.lat[::1])

ax[1,0].plot(coords3.lon[::1], coords3.lat[::1])

ax[1,1].plot(coords4.lon[::1], coords4.lat[::1])

ax[2,0].plot(coords5.lon[::1], coords5.lat[::1])

ax[2,1].plot(coords6.lon[::1], coords6.lat[::1])

plt.show()

# %% [markdown]
# ### 3차 같은 출발지 제외

# %%
with open('C:/Users/박연재/Desktop/국립공원공단/트랭글데이터/2019_done/done_997163.gpx', encoding='utf-8') as fh:
    gpx_file1 = gpxpy.parse(fh)
segment1 = gpx_file1.tracks[0].segments[0]
coords1 = pd.DataFrame([
    {'idx':0,
     'lat': p.latitude, # 포인트 위도
     'lon': p.longitude, # 포인트 경도
     'ele': p.elevation, # 포인트 고도
     'time': p.time} for p in segment1.points]) # 포인트 시간


with open('C:/Users/박연재/Desktop/국립공원공단/트랭글데이터/2019_done/done_883554.gpx', encoding='utf-8') as fh:
    gpx_file2 = gpxpy.parse(fh)
segment2 = gpx_file2.tracks[0].segments[0]
coords2 = pd.DataFrame([
    {'idx':1,
     'lat': p.latitude,
     'lon': p.longitude,
     'ele': p.elevation,
     'time': p.time} for p in segment2.points])

with open('C:/Users/박연재/Desktop/국립공원공단/트랭글데이터/2019_done/done_1471251.gpx',encoding='utf-8') as fh:
    gpx_file3 = gpxpy.parse(fh)
segment3 = gpx_file3.tracks[0].segments[0]
coords3 = pd.DataFrame([
    {'idx':2,
     'lat': p.latitude,
     'lon': p.longitude,
     'ele': p.elevation,
     'time': p.time} for p in segment3.points])

with open('C:/Users/박연재/Desktop/국립공원공단/트랭글데이터/2019_done/done_638366.gpx',encoding='utf-8') as fh:
    gpx_file4 = gpxpy.parse(fh)
segment4 = gpx_file4.tracks[0].segments[0]
coords4 = pd.DataFrame([
    {'idx':3,
     'lat': p.latitude,
     'lon': p.longitude,
     'ele': p.elevation,
     'time': p.time} for p in segment4.points])

with open('C:/Users/박연재/Desktop/국립공원공단/트랭글데이터/2019_done/done_4551553.gpx',encoding='utf-8') as fh:
    gpx_file5 = gpxpy.parse(fh)
segment5 = gpx_file5.tracks[0].segments[0]
coords5 = pd.DataFrame([
    {'idx':4,
     'lat': p.latitude,
     'lon': p.longitude,
     'ele': p.elevation,
     'time': p.time} for p in segment5.points])

with open('C:/Users/박연재/Desktop/국립공원공단/트랭글데이터/2019_done/done_924117.gpx',encoding='utf-8') as fh:
    gpx_file6 = gpxpy.parse(fh)
segment6 = gpx_file6.tracks[0].segments[0]
coords6 = pd.DataFrame([
    {'idx':4,
     'lat': p.latitude,
     'lon': p.longitude,
     'ele': p.elevation,
     'time': p.time} for p in segment6.points])

# %%
#plt.figure(figsize=(10,10))

plt.plot(coords1.lon[::1], coords1.lat[::1])
plt.plot(coords2.lon[::1], coords2.lat[::1])
plt.plot(coords3.lon[::1], coords3.lat[::1])
plt.plot(coords4.lon[::1], coords4.lat[::1])
plt.plot(coords5.lon[::1], coords5.lat[::1])
plt.plot(coords6.lon[::1], coords6.lat[::1])

plt.show()

# %%
fig,ax=plt.subplots(nrows=3,ncols=2)

ax[0,0].plot(coords1.lon[::1], coords1.lat[::1])

ax[0,1].plot(coords2.lon[::1], coords2.lat[::1])

ax[1,0].plot(coords3.lon[::1], coords3.lat[::1])

ax[1,1].plot(coords4.lon[::1], coords4.lat[::1])

ax[2,0].plot(coords5.lon[::1], coords5.lat[::1])

ax[2,1].plot(coords6.lon[::1], coords6.lat[::1])

plt.show()

# %% [markdown]
# ### 4차 같은 출발지 제외

# %%
with open('C:/Users/박연재/Desktop/국립공원공단/트랭글데이터/2019_done/done_1000362.gpx', encoding='utf-8') as fh:
    gpx_file1 = gpxpy.parse(fh)
segment1 = gpx_file1.tracks[0].segments[0]
coords1 = pd.DataFrame([
    {'idx':0,
     'lat': p.latitude, # 포인트 위도
     'lon': p.longitude, # 포인트 경도
     'ele': p.elevation, # 포인트 고도
     'time': p.time} for p in segment1.points]) # 포인트 시간


with open('C:/Users/박연재/Desktop/국립공원공단/트랭글데이터/2019_done/done_5325291.gpx', encoding='utf-8') as fh:
    gpx_file2 = gpxpy.parse(fh)
segment2 = gpx_file2.tracks[0].segments[0]
coords2 = pd.DataFrame([
    {'idx':1,
     'lat': p.latitude,
     'lon': p.longitude,
     'ele': p.elevation,
     'time': p.time} for p in segment2.points])

with open('C:/Users/박연재/Desktop/국립공원공단/트랭글데이터/2019_done/done_973919.gpx',encoding='utf-8') as fh:
    gpx_file3 = gpxpy.parse(fh)
segment3 = gpx_file3.tracks[0].segments[0]
coords3 = pd.DataFrame([
    {'idx':2,
     'lat': p.latitude,
     'lon': p.longitude,
     'ele': p.elevation,
     'time': p.time} for p in segment3.points])

with open('C:/Users/박연재/Desktop/국립공원공단/트랭글데이터/2019_done/done_4075530.gpx',encoding='utf-8') as fh:
    gpx_file4 = gpxpy.parse(fh)
segment4 = gpx_file4.tracks[0].segments[0]
coords4 = pd.DataFrame([
    {'idx':3,
     'lat': p.latitude,
     'lon': p.longitude,
     'ele': p.elevation,
     'time': p.time} for p in segment4.points])

with open('C:/Users/박연재/Desktop/국립공원공단/트랭글데이터/2019_done/done_2020075.gpx',encoding='utf-8') as fh:
    gpx_file5 = gpxpy.parse(fh)
segment5 = gpx_file5.tracks[0].segments[0]
coords5 = pd.DataFrame([
    {'idx':4,
     'lat': p.latitude,
     'lon': p.longitude,
     'ele': p.elevation,
     'time': p.time} for p in segment5.points])

with open('C:/Users/박연재/Desktop/국립공원공단/트랭글데이터/2019_done/done_4717246.gpx',encoding='utf-8') as fh:
    gpx_file6 = gpxpy.parse(fh)
segment6 = gpx_file6.tracks[0].segments[0]
coords6 = pd.DataFrame([
    {'idx':4,
     'lat': p.latitude,
     'lon': p.longitude,
     'ele': p.elevation,
     'time': p.time} for p in segment6.points])

# %%
#plt.figure(figsize=(10,10))

plt.plot(coords1.lon[::1], coords1.lat[::1])
plt.plot(coords2.lon[::1], coords2.lat[::1])
plt.plot(coords3.lon[::1], coords3.lat[::1])
plt.plot(coords4.lon[::1], coords4.lat[::1])
plt.plot(coords5.lon[::1], coords5.lat[::1])
plt.plot(coords6.lon[::1], coords6.lat[::1])

plt.show()

# %%
fig,ax=plt.subplots(nrows=3,ncols=2)

ax[0,0].plot(coords1.lon[::1], coords1.lat[::1])

ax[0,1].plot(coords2.lon[::1], coords2.lat[::1])

ax[1,0].plot(coords3.lon[::1], coords3.lat[::1])

ax[1,1].plot(coords4.lon[::1], coords4.lat[::1])

ax[2,0].plot(coords5.lon[::1], coords5.lat[::1])

ax[2,1].plot(coords6.lon[::1], coords6.lat[::1])

plt.show()

# %% [markdown]
# ### 5차 같은 출발지에서 선택

# %%
with open('C:/Users/박연재/Desktop/국립공원공단/트랭글데이터/2019_done/done_1000362.gpx', encoding='utf-8') as fh:
    gpx_file1 = gpxpy.parse(fh)
segment1 = gpx_file1.tracks[0].segments[0]
coords1 = pd.DataFrame([
    {'idx':0,
     'lat': p.latitude, # 포인트 위도
     'lon': p.longitude, # 포인트 경도
     'ele': p.elevation, # 포인트 고도
     'time': p.time} for p in segment1.points]) # 포인트 시간


with open('C:/Users/박연재/Desktop/국립공원공단/트랭글데이터/2019_done/done_3535115.gpx', encoding='utf-8') as fh:
    gpx_file2 = gpxpy.parse(fh)
segment2 = gpx_file2.tracks[0].segments[0]
coords2 = pd.DataFrame([
    {'idx':1,
     'lat': p.latitude,
     'lon': p.longitude,
     'ele': p.elevation,
     'time': p.time} for p in segment2.points])

with open('C:/Users/박연재/Desktop/국립공원공단/트랭글데이터/2019_done/done_1897002.gpx',encoding='utf-8') as fh:
    gpx_file3 = gpxpy.parse(fh)
segment3 = gpx_file3.tracks[0].segments[0]
coords3 = pd.DataFrame([
    {'idx':2,
     'lat': p.latitude,
     'lon': p.longitude,
     'ele': p.elevation,
     'time': p.time} for p in segment3.points])

with open('C:/Users/박연재/Desktop/국립공원공단/트랭글데이터/2019_done/done_1928153.gpx',encoding='utf-8') as fh:
    gpx_file4 = gpxpy.parse(fh)
segment4 = gpx_file4.tracks[0].segments[0]
coords4 = pd.DataFrame([
    {'idx':3,
     'lat': p.latitude,
     'lon': p.longitude,
     'ele': p.elevation,
     'time': p.time} for p in segment4.points])

with open('C:/Users/박연재/Desktop/국립공원공단/트랭글데이터/2019_done/done_4666952.gpx',encoding='utf-8') as fh:
    gpx_file5 = gpxpy.parse(fh)
segment5 = gpx_file5.tracks[0].segments[0]
coords5 = pd.DataFrame([
    {'idx':4,
     'lat': p.latitude,
     'lon': p.longitude,
     'ele': p.elevation,
     'time': p.time} for p in segment5.points])

with open('C:/Users/박연재/Desktop/국립공원공단/트랭글데이터/2019_done/done_2121608.gpx',encoding='utf-8') as fh:
    gpx_file6 = gpxpy.parse(fh)
segment6 = gpx_file6.tracks[0].segments[0]
coords6 = pd.DataFrame([
    {'idx':4,
     'lat': p.latitude,
     'lon': p.longitude,
     'ele': p.elevation,
     'time': p.time} for p in segment6.points])

# %%
#plt.figure(figsize=(10,10))

plt.plot(coords1.lon[::1], coords1.lat[::1])
plt.plot(coords2.lon[::1], coords2.lat[::1])
plt.plot(coords3.lon[::1], coords3.lat[::1])
plt.plot(coords4.lon[::1], coords4.lat[::1])
plt.plot(coords5.lon[::1], coords5.lat[::1])
plt.plot(coords6.lon[::1], coords6.lat[::1])

plt.show()

# %%
fig,ax=plt.subplots(nrows=3,ncols=2)

ax[0,0].plot(coords1.lon[::1], coords1.lat[::1])

ax[0,1].plot(coords2.lon[::1], coords2.lat[::1])

ax[1,0].plot(coords3.lon[::1], coords3.lat[::1])

ax[1,1].plot(coords4.lon[::1], coords4.lat[::1])

ax[2,0].plot(coords5.lon[::1], coords5.lat[::1])

ax[2,1].plot(coords6.lon[::1], coords6.lat[::1])

plt.show()
